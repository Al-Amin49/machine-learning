# %%
"""
*Topics Covered
• Events, sample space, and basic probability rules
• Conditional probability and independence
• Bayes’ theorem (intuitive and formula-level) and base-rate effects
• Sensitivity, specificity, false positive/negative rates, PPV, and NPV
• Class imbalance and its impact on interpreting errors
"""

# P(Event)=Favorable outcomes/Total outcomes --> 3/6 (akta sokka gutie even number ashar possiblity 3)
# Out:
# Hello world
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
"""
Conditional Probability is the probability of A given that B has occured.

- Example: P(Person buys ice cream) | Hot day.
* It answers how one factor changes the likelihood of another

*Independence: Events A and B are independent if P(A|B)= P(A)

# ?Bayes' Theorem and Base-Rate effects:

"""

#2-2 Events, sample space, and basic probability rules
""" 
? Probability is simple a measure of uncertainty. It tells us how likely something to happen

P(Event) = Number of Favourable outcomes/Total number of outcomes

# ?Sample Space:  all possible outcomes.

When you toss a coin:
S = {Heads, Tails}
When you roll a die:
S = {1,2,3,4,5,6}

Events can be:
• Simple event: one outcome (like rolling a 3)
• Compound event: multiple outcomes (like rolling an even number)
• Complementary event: everything else (not rolling an even number)
P(E^c) --> Event na hower possibility
P(E) --> Event hower possibility

# !P(E^c)=1-P(E)

? Basic Probability
? Conditional Probability

* Conditional probability measures how likely one event is given that another event has occured.

P(A|B) --> B already ocurred hoye gese atar upore depend kore A er probability koto


"""

# %%
"""
# ?Confusion Matrix

# !Imagine a hospital testing people for a disease called X-virus.

1,000 people are tested
100 actually have the disease
900 are healthy

Reality/Test	Test Positive	Test Negative
Disease	          90	             10
No Disease	      50                   	850

🟢 TP — True Positive = 90
Meaning (in words)

The person actually has the disease
AND
The test correctly says “Positive”

Story version

90 people were really sick
The test correctly detected them
✅ Correct detection

# ?Why it matters

High TP = good at catching real cases
Important in medical screening, fraud detection, terrorism detection

🔴 FN — False Negative = 10
Meaning

The person actually has the disease
BUT
The test says “Negative”

Story version

10 sick people were told:
“You’re healthy”
❌ Dangerous mistake

# ?Why it matters
These people don’t get treatment
FN is the most dangerous error in medicine

🔴 FP — False Positive = 50
Meaning

The person does NOT have the disease
BUT
The test says “Positive”



50 healthy people were told:
“You’re sick”
❌ False alarm

Why it matters

Causes fear, stress, extra tests

In ML: blocks normal emails, flags normal users

🟢 TN — True Negative = 850
Meaning

The person does NOT have the disease
AND
The test correctly says “Negative”

Story version

850 healthy people were correctly told:

“You’re healthy”

✅ Correct rejection

Why it matters

High TN = trust in negative results

Saves money, time, and worry
"""

""" 
# !onek kisu kathay note ase. katha + note er shomonnoye porte hobe

*Class imbalance

# ?Class imbalance occurs when one class is much more frequent than the other.

Example
Fraud transactions: 1% fraud, 99% normal
Disease screening: 0.5% sick, 99.5% healthy
Spam detection: 20% spam, 80% normal
➡️ One class dominates the dataset.
"""
