# %%
"""
! Module 1: Descriptive statistics and distributions 

1-1 Introduction
1-2 Mean, Median, mode when each is appropriate
1-3 Variance and standard deviation as measures speed
1-4 Percentiles, quartiles, IQR, and z-score
1-5 Distribution shapes symmetric vs skewed, long tails, outlier detection with IQR fences
1-6 When median and IQR are preffered over mean and standard deviation
1-7 conclusion
"""
#Akane ML er jonno statistics shika hobe not for data science. Data science er jonno deep statistics lage

#1-1 introduction

"""
? Statistics
* Statistics is the science of working with data --> collecting, summarizing, analyzing, and interpreting it to understand the real world through numbers.
# !Example
- Suppose we collect the marks of all students in a class.
- The mean tells us the class's average performance
- the median shows the middle score

# ?Remember: We’re not training to be statisticians, but to use statistics as a tool to make machine learning models accurate, robust, and explainable.

# !Types of statistics
- Descriptive statistics
- Inferential statistics
"""
# Out:
# "\n? Statistics\n* Statistics is the science of working with data --> collecting, summarizing, analyzing, and interpreting it to understand the real world through numbers.\n!Example\n- Suppose we collect the marks of all students in a class.\n- The mean tells us the class's average performance\n- the median shows the middle score\n\n?Remember: We’re not training to be statisticians, but to use statistics as a tool to make machine learning models accurate, robust, and explainable.\n"

# %%
# 1-2 Mean Median Mode when each is appropriate


import numpy as np
import pandas as pd

# Simple dataset (e.g., house prices in thousands)
data = [120, 125, 128, 122, 126, 124, 600]  # 600 is an outlier
df = pd.DataFrame({'HousePrice': data})

# Mean
mean_value = df['HousePrice'].mean()
print("Mean:", mean_value)
     
Mean: 192.14285714285714

median_value = df['HousePrice'].median()
print("Median:", median_value)
     
Median: 125.0

# Adding some categorical data
df['City'] = ['Dhaka', 'Dhaka', 'Chattogram', 'Sylhet', 'Dhaka', 'Rajshahi', 'Chattogram']
mode_value = df['City'].mode()[0]
print("Mode:", mode_value)
# Out:
# Mean: 192.14285714285714
# Median: 125.0
# Mode: Dhaka

# %%
# 1-3 Variance and standard deviation as measures of spread
"""
*Population variance k n diye divide kortesi,Sample variance k n-1 diye divide kortesi atake bola hoy Bessel's correction.
! Keno bessel's correction hoy
- because sample variance ta high korar jonno jate sheta bias free hoy.

"""

"""
# !Standard deviation vs Variance
? Variance and STD duitai bole apnar j data point mean value or average value teke koto dure
- Outliers(amon j majority value teke different)

# !kisu note kathay ase
*Variance is a measure of the spread or dispersion of a set of data points. It is calculated as the average of the squared differences from the mean.

1.1 -1.4 note kathay

"""

"""
*1-5 Distribution shapes symmetric vs skewed, long tails, outlier detection with IQR fences

- symmetric distribution
- skewed distribution
- Long Tails and Their Significance
- Outlier Detection using IQR Fences
- When to Keep vs. Remove Outliers
! Recap and summary
Let’s summarize what we learned:
✅ Symmetric distributions make ML models more stable.
✅ Skewed or long-tailed data often need transformation.
✅ IQR is a quick and effective outlier detection method.
✅ Always analyze whether outliers represent noise or valuable insight.
Understanding data shape is the first step toward building trustworthy ML models


*1-6 When median and IQR are preferred over mean and standard deviation


"""

# %%
# Quiz
"""

- The difference between the highest and lowest values in a dataset is called - range
- Which measure of spread is based on the middle 50% of the data -Interquartile Range (IQR) 
"""
